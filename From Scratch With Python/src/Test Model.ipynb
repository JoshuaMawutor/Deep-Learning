# %%
from Regularization import *

# %%
from sklearn.model_selection import train_test_split

# %%
path = "C:\Users\Dell\PycharmProjects\Deep Learning\cat_dog"
# Out:
#   Cell In[7], line 1
#     path = "C:\Users\Dell\PycharmProjects\Deep Learning\cat_dog"
#            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
images = []
label = []
for i in os.listdir(path):
    if i.endswith('jpg') or i.endswith('png'):
        elements = os.path.join(path, i)
        img = cv2.imread(elements)
        img = cv2.resize(img, (64,64))
        images.append(img)
        if i.startswith('dog'):
            lab = 1
        else:
            lab = 0
        label.append(lab)
Images = np.array(images)
Label = np.array(label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 images = []
#       2 label = []
# ----> 3 for i in os.listdir(path):
#       4     if i.endswith('jpg') or i.endswith('png'):
#       5         elements = os.path.join(path, i)
#       6         img = cv2.imread(elements)
#
# NameError: name 'os' is not defined

# %%
B = np.array(B)
c = np.array(c)

B_train, B_test, c_train, c_test = train_test_split(B,c, test_size=0.2)
print(B_train.shape)
print(B_test.shape)
print(c_train.shape)
print(c_test.shape)
print(B_train.shape[0])
# Out:
# (455, 30)
# (114, 30)
# (455,)
# (114,)
# 455

# %%
B_train = B_train.reshape(B_train.shape[0], B_train.shape[1]).T
B_test =  B_test.reshape(B_test.shape[0], B_test.shape[1]).T
c_train = c_train.reshape(c_train.shape[0],-1).T
c_test = c_test.reshape(c_test.shape[0],-1).T
print(B_train.shape)
print(B_test.shape)
print(c_train.shape)
print(c_test.shape)
# Out:
# (30, 455)
# (30, 114)
# (1, 455)
# (1, 114)

# %%
alls = Models(B_train,c_train,20000,print_cost=True)
# Out:
# Epochs: 0: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.693113338289081
# Epochs: 1000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.6726021174015944
# Epochs: 2000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.5129734281166358
# Epochs: 3000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.27824972205639426
# Epochs: 4000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.22108692603215377
# Epochs: 5000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.25126114695686574
# Epochs: 6000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.21080837640320307
# Epochs: 7000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.20778544846070457
# Epochs: 8000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.2051045107042353
# Epochs: 9000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.20286249317561098
# Epochs: 10000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.20065011659924176
# Epochs: 11000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.198744006087519
# Epochs: 12000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.19697168400237403
# ...

# %%
from Regularization_p2 import *

# %%
params = model(B_train,c_train, 20000,0.7, print_cost=True)
# Out:
# Epochs: 0: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.6932116709899105
# Epochs: 1000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.6570571003862703
# Epochs: 2000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.47872414017771114
# Epochs: 3000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.4157539449395059
# Epochs: 4000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.30601584079587907
# Epochs: 5000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.2639366694900416
# Epochs: 6000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.25692531945608726
# Epochs: 7000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.23503785714472827
# Epochs: 8000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.2316073196300506
# Epochs: 9000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.2243854185071861
# Epochs: 10000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.2168013438145474
# Epochs: 11000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.20546155102424157
# Epochs: 12000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.18985789208952825
# ...

# %%
params2 = model(B_train,c_train, 20000,0.8, print_cost=True)
# Out:
# Epochs: 0: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.693375715957977
# Epochs: 1000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.6667837337698009
# Epochs: 2000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.5551740957092809
# Epochs: 3000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.44650327844650267
# Epochs: 4000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.3641390775150834
# Epochs: 5000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.3225271485163981
# Epochs: 6000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.30578385118048745
# Epochs: 7000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.2758183358926134
# Epochs: 8000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.25288492932692735
# Epochs: 9000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.24193280703874392
# Epochs: 10000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.23887459195237365
# Epochs: 11000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.23610828234244685
# Epochs: 12000: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.22990401835292978
# ...

# %%
from Regularization_p3 import *

# %%
#regs = model_L2reg(B_train,c_train,20000,2,0.01,print_cost=True)

# %%
from Regularization_all import *

# %%
another = models_all(B_train,c_train,0.01,0.8,0,20000,print_cost=True)
# Out:
# Epochs: 0: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.6929191803898567, Accuracy: 0.6395604395604395
# Epochs: 100: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.6115671444864872, Accuracy: 0.676923076923077
# Epochs: 200: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.5624199679057783, Accuracy: 0.7934065934065934
# Epochs: 300: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.4020763505006047, Accuracy: 0.8527472527472527
# Epochs: 400: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.33925511767094296, Accuracy: 0.8945054945054945
# Epochs: 500: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.33142729519090014, Accuracy: 0.8571428571428571
# Epochs: 600: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.509005899321403, Accuracy: 0.8307692307692308
# Epochs: 700: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.2869477025485138, Accuracy: 0.8945054945054945
# Epochs: 800: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.2848996692394885, Accuracy: 0.8967032967032967
# Epochs: 900: >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cost: 0.2692594232834923, Accuracy: 0.9010989010989011
# ...

# %%
another
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 another
#
# NameError: name 'another' is not defined
